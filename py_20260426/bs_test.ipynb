# %%
from crawl_test import response
import requests
from bs4 import BeautifulSoup as bs

response = requests.get("https://startcoding.pythonanywhere.com/basic")
html = response.text
soup = bs(html, 'html.parser')
soup.select_one('.brand-name')
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="google-site-verification" content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_260205.css"> <link rel="canonical" href="https://www.naver.com/"> <link rel="alternate" media="only screen and (max-width: 767px)" href="https://m.naver.com/"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"김기민, 관능의 17분으로 '전설의 계보' 잇다","url":"https://n.news.naver.com/article/015/0005279672","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fimgnews%2Fimage%2F015%2F2026%2F04%2F26%2F0005279672_001_20260426171711823.jpg%22&type=ff364_236&service=navermain"},"source":{"url":"https://media.naver.com/press/015","name":"한국경제","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fmimgnews%2Fimage%2Fupload%2Foffice_logo%2F015%2F2025%2F03%2F07%2Flogo_015_100_20250307145644.png%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"68a6cf09a173986b7a52e5eb"},{"@type":"MATERIAL-PC-FEED","title":"마흔이 되면 “반드시 버려야 하는 18가지”","url":"https://blog.naver.com/smallbigmedia/224250710845","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNjA0MTNfMjE5%2FMDAxNzc2MDU5MDM0NDgx.yUbkeWjVP8OdZD5tIe6SHGQZvxoOdfBYI8nxv5TIR_Ig.2Tgr2F8IrW1fz9_S2YO82zro-PTRSp8DizcxHmgBjz8g.JPEG%2Ftask_01kp2nt152fggb89gpwzt32cfn_1776058980_img_0.jpg%22&type=ff364_236&service=navermain"},"source":{"url":"https://blog.naver.com/smallbigmedia","name":"오분서가","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyNDA4MTZfMTEw%2FMDAxNzIzNzY3NzMzMDgz.Exh4EqrRgfeJDl8PhBFllgobLnmIDRUK189OMQB6s9sg.zH3FhgWXEcZz0XJlFgEZEnQJx2iQKx6a1wcz9K0KICQg.PNG%2Fgjhkjhk.png%2Fgjhkjhk.png%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"68a6cf09a173986b7a52e5ec"},{"@type":"MATERIAL-PC-FEED","title":"미국에서 발견된 세상에서 가장 위험한 물고기","url":"https://in.naver.com/tamsatube/contents/internal/939392891340640","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNjA0MDhfMTQ0%2FMDAxNzc1NjQ0NTM3OTc3.tlXFSUwA_VwJM_Sy0lvYjgr1_HIffrkfwcmm3wZoe9wg.IjVS01tA_0zZrj02slI5lE2uws5C8kRGnV8RpZ0qNqAg.PNG%2Fimage.png%22&type=ff364_236&service=navermain"},"source":{"url":"https://blog.naver.com/tamsatube","name":"탐사튜브","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyNjA0MTRfMjYg%2FMDAxNzc2MTMwMjg5Mzkw.CMCLhfigVUHd0g6eKpXHnPUrapx5_3JgLEI3DiJ6Dbsg.pmwyjmvc8S7zEc1dm-4jV-WaWOARBO7H9B6bseE0zdgg.PNG%2F%25EB%25A1%259C%25EA%25B3%25A0.png%2F%25EB%25A1%259C%25EA%25B3%25A0.png%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"68a6cf09a173986b7a52e5ed"},{"@type":"MATERIAL-PC-FEED","title":"메탈릭한 느낌의 페인트 마커  #그래피티 #레터링 #캘리그라피 #영문캘리 #손글씨 #필기체 #펜 #잉크 #만년필 #문구","url":"https://m.naver.com/shorts?serviceType=CLIP&mediaType=VOD&seedMediaId=FEA5E38FF9B7EC5B30F187E7079F079CC619&recType=CLIP_PC&recId=%7B%22targetProfileId%22%3A%22sloleecalli%22%2C%22open%22%3Atrue%7D","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fclip-service-phinf.pstatic.net%2FMjAyNjA0MjZfMjgx%2FMDAxNzc3MTM0NzYzNDI0.NJkX5iIguw6u5m4y8ZMNvBwPqwRRF--ZciHAV9QFzu4g.4y_JlKjwZg7S3KDpbx2TLeKEQhSZWP_u_hYnFYYQINEg.JPEG%2Fthumbnail-6E0F9479-1C8B-465C-B16E-81E2B7C20FDD.jpg%22&type=ff364_236&service=navermain"},"source":{"url":"https://clip.naver.com/@sloleecalli","name":"알파벳 너드 슬로리","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fclip-service-phinf.pstatic.net%2FMjAyNjAyMjZfMTU0%2FMDAxNzcyMTAyMzk3MTAy.nKVxO-fetoxGC8gtmJ98Y9esKYsRyHRVUqOIWx12NWcg.mvZ79oNByL63MAT53vwGLq0UNKDtffaArjrQXY1E_iEg.JPEG%2Fimage.jpg%22&type=nf40_40&service=navermain"}},"video":{"playTime":"00:49"},"showLiveBadge":false,"_id":"68a6cf09a173986b7a52e5ee"},{"@type":"MATERIAL-PC-FEED","title":"병아리를 바닥에 던지는 이유 출처 : youbue @UnloadingHatchery @OldChicks","url":"https://m.naver.com/shorts?serviceType=CLIP&mediaType=VOD&seedMediaId=302F29B2C31947E30FA17E48F7778B839E76&recType=CLIP_PC&recId=%7B%22targetProfileId%22%3A%22totostory%22%2C%22open%22%3Atrue%7D","image":{"url":"https://s.pstatic.net/dthumb.phinf/?sr ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"ea7aeadb-417c-11f1-a1f5-9d4026fde85d","@provider":"lambda","@lastModifiedAt":[2026,4,26,14,33,39,113000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260426 22:07:43","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260426 16:03:36","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260426 23:11:09","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181433494.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181453897.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260425 07:50:38","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260426 23:25:15","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260424 09:26:10","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20260426 20:25:50","_id":null,"@type":"PC-N ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"美법무장관 대행 \"총격범, 대통령 노렸을 가능성\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016043787","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"이란 외무, 하루만에 다시 종전 중재국 파키스탄으로","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016043796","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec43489"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"케냐 사웨, 런던 마라톤서 1시간59분30초…마라톤 2시간 벽 깼다","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016043780","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348a"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"김영훈 \"단기근로자 위한 공정수당 도입…정년연장 상반기 결론\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016043655","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"법무장관 \"검찰, 尹 정적제거 부역 비판…국민 분노 공감해야\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016043677","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"699a2f03b31ea2c7bf39fcb5"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"가평 골프장서 10만명 개인정보 유출…북한 해킹 가능성","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016043764","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"699a2f03b31ea2c7bf39fcb6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'고유가 지원금' 1차 지급 내일부터…취약계층 우선 대상","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016043120","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"699a2f03b31ea2c7bf39fcb7"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"이스라엘-레바논 휴전 사실상 무력화…드론 공격에 공습 맞불","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016043785","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"69bf926ad7560e7adfc11bcc"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"여자농구 KB, 싹쓸이로 4년 만에 통합 우승…챔프전 MVP 허예은","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0016043607","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"69c0a59263dc8b7c9330c150"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"월요일 전국 대체로 흐려…밤부터 수도권·강원·충청에 비","url ...
# window["EAGER-DATA"]["PC-PREMIUM-AD"] = {"@type":"PC-PREMIUM-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N010","adlineId":null,"vimp100p0s":null,"assets":null,"vimp50p1s":"https://siape.veta.naver.com/fxview?eu=EU10044434&calp=-&oj=UDLDkoMX9MNQsbHfqBkowpfAu9XDXnAolNPt8UsqU9Fb1semBhH3ZSGNcbrnFmKn&ac=8206821&src=4733402&evtcd=V900&x_ti=1362&tb=&oid=&sid1=&sid2=&rk=hjoKkKq0CD4wVHbHmmo7iQ&eltts=%2FBNIvh3tFFUKLuTMsv%2BvbQ%3D%3D&brs=Y&&eid=V900"},"_id":null,"@type":null,"@code":"PC-PREMIUM-AD","@template":"PC-PREMIUM-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["PC-MYSERVICE-META"] = {"@type":"PC-MYSREVICE-META","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"serviceMetaList":[],"_id":"68414a73a10d30068523e7ee","@type":"MY-SERVICE-META-BLOCK","@code":"PC-MYSERVICE-META","@template":"NONE","@flowId":"PC-MYSERVICE-META","@flowExecutionId":"b901344e-417c-11f1-8dc2-97cccfb04255","@provider":"lambda","@lastModifiedAt":[2026,4,26,14,32,16,111000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"a1bf87bb-417c-11f1-b994-cfdd84b7037d","@provider":"lambda","@lastModifiedAt":[2026,4,26,14,31,37,93000000]}
# window["EAGER-DATA"]["PC-HEADLINE-AD"] = {"@type":"PC-HEADLINE-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N402","adlineId":"3118635","vimp100p0s":"https://siape.veta.naver.com/fxview?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FJfAu9XDXnAolNPt8UsqU9Fb1semBhH3ZSGNcbrnFmKn&ac=9273574&src=8059656&evtcd=V900&x_ti=1587&tb=&oid=&sid1=&sid2=&rk=t-uCXwoeP-RBCSZa3qgF-Q&eltts=%2FBNIvh3tFFUKLuTMsv%2BvbQ%3D%3D&brs=Y&&eid=V900","assets":{"hl_web_img":{"url":"https://ssl.pstatic.net/melona/libs/1564/1564335/17f3ebe1280c68f00ebc_20260402141820324.png","alt":"[광고]네이버부터 AI검색까지, 웨일로 똑똑하게 일하는 방법","w":488,"h":216},"hl_web_img_dark":{"url":"https://ssl.pstatic.net/melona/libs/1564/1564335/1d809b723434317eccad_20260402141824639.png","alt":"[광고]네이버부터 AI검색까지, 웨일로 똑똑하게 일하는 방법","w":488,"h":216},"hl_link":{"url":"https://siape.veta.naver.com/fxclick?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FJfAu9XDXnAolNPt8UsqU9Fb1semBhH3ZSGNcbrnFmKn&ac=9273574&src=8059656&br=4918438&evtcd=P901&x_ti=1587&tb=&oid=&sid1=&sid2=&rk=t-uCXwoeP-RBCSZa3qgF-Q&eltts=%2FBNIvh3tFFUKLuTMsv%2BvbQ%3D%3D&brs=Y&&a=8BC69A861109E57D8DA7317B6D19935012FD2618C1EFEFB57A3F248306F857FCF1E5402470342D4EAFFEE51A172FCAFF2A77FDF91E680438DDCDF99CC0C6BFF6","clicktracking":"https://ssl.pstatic.net/tveta/libs/1by1.gif"},"bb_web_img":null,"bb_web_img_dark":null,"bb_link":null,"bb_web_text":null}},"_id":null,"@type":null,"@code":"PC-HEADLINE-AD","@template":"PC-HEADLINE-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"a8e86a3b-417c-11f1-8dc2-a9ee5f5075d9","@provider":"lambda","@lastModifiedAt":[2026,4,26,14,31,49,101000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"9e4b703d-417c-11f1-b9df-d9416ff0098c","@provider":"lambda","@lastModifiedAt":[2026,4,26,14,31,31,322000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":false,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2026-04-23T15:05:41.533"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.shpt","name":"쇼핑투데이","id":"PC-MEDIA-SHOPPING-TODAY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.game","name":"게임","id":"PC-MEDIA-GAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2026-04-23T18:08:56.038"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"ab5fabd3-417c-11f1-8dc2-9d3fcf707b36","@provider":"lambda","@lastModifiedAt":[2026,4,26,14,31,53,239000000]}
# </script>
#
#
#  <script>!function(){var e=Math.random()<1;const n={"s.pstatic.net":"s.naver.net","pm.pstatic.net":"pm.naver.net","mm.pstatic.net":"mm.naver.net","mml.pstatic.net":"mml.naver.net"};window.nmain=window.nmain||{},window.nmain&&(window.nmain.cdnFallbackLogQueue=[]);function t(e){try{if(!window.nmain)return;if(Math.random()>=.01)return;var n=new Error(e);window.nmain.sendInfo?window.nmain.sendInfo(n):window.nmain.cdnFallbackLogQueue&&window.nmain.cdnFallbackLogQueue.push(n)}catch(e){}}function r(e,t){const r=new URL(e),a=n[r.hostname];if(!a)return e;if(e.includes(".cdnfallback."))return e;r.hostname=a;const c=new RegExp(`\\.(${t})$`,"i");return r.pathname=r.pathname.replace(c,".cdnfallback.$1"),r.toString()}window.addEventListener("error",a=>{const{target:c}=a;if(e)if(c.dataset&&"done"===c.dataset.cdnFallbackAttempt)c instanceof HTMLImageElement?t("[CDN Fallback] fallback img resource load failed: "+c.src):c instanceof HTMLLinkElement?t("[CDN Fallback] fallback css resource load failed: "+c.href):c instanceof HTMLScriptElement&&t("[CDN Fallback] fallback js resource load failed: "+c.src);else if(c instanceof HTMLImageElement){var o=c.src;(function(e,t){if(!e.src)return!1;const r=new URL(e.src),a=n[r.hostname];if(!a)return!1;t.stopImmediatePropagation(),t.preventDefault();var c=r.hostname;if(r.hostname=a,e.src=r.toString(),e.srcset&&(e.srcset=e.srcset.split("//"+c).join("//"+a)),e.parentElement&&e.parentElement instanceof HTMLPictureElement)for(var o=e.parentElement.querySelectorAll("source"),i=0;i<o.length;i++){var s=o[i];s.srcset&&Object.keys(n).forEach(function(e){s.srcset=s.srcset.split("//"+e).join("//"+n[e])})}return e.dataset.cdnFallbackAttempt="done",!0})(c,a)&&t("[CDN Fallback] origin img resource load failed: "+o)}else c instanceof HTMLLinkElement?function(e){if(!e.href||"done"===e.dataset.cdnFallbackAttempt)return!1;const n=r(e.href,"css");if(n!==e.href){const t=document.createElement("link");return t.rel="stylesheet",t.href=n,t.dataset.cdnFallbackAttempt="done",e.onerror&&(t.onerror=e.onerror),e.type&&(t.type=e.type),e.media&&(t.media=e.media),e.parentNode&&e.parentNode.insertBefore(t,e.nextSibling),!0}return!1}(c)&&t("[CDN Fallback] origin css resource load failed: "+c.href):c instanceof HTMLScriptElement&&function(e){if(!e.src||"done"===e.dataset.cdnFallbackAttempt)return!1;const n=r(e.src,"js");if(n!==e.src){const t=document.createElement("script");return t.src=n,t.crossOrigin=e.crossOrigin,t.async=e.async,t.defer=e.defer,t.dataset.cdnFallbackAttempt="done",e.onerror&&(t.onerror=e.onerror),e.type&&(t.type=e.type),e.parentNode&&e.parentNode.insertBefore(t,e.nextSibling),!0}return!1}(c)&&t("[CDN Fallback] origin js resource load failed: "+c.src)},{capture:!0})}()</script> <script defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.e72edbd6.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/preload.abfce3a1.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/search.dc3e1331.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/main.9b971cfc.js?o=www" crossorigin="anonymous"></script><link href="https://pm.pstatic.net/resources/css/main.1407a643.css" rel="stylesheet"></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div>   <script type="text/plain" id="ad-timeboard-response" data-gfp-banner-size="830x130" data-gfp-banner-type="full">{"payload":{"requestId":"85f7d121be6641ebb61756755a0d1666","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{" ...
# </script> <div id="wrap"> <div id="whale-banner"></div> <div id="header" role="banner"> <div id="topSearchWrap" class="header_inner"> <div id="special-logo" class="search_special_bg"></div> <div id="timeboard-ex" class="ad_area" style="width:1280px"> </div> <div id="search_area" class="search_area" style="border-color:#fff"> <div class="search_group"> <div id="search" class="search_group_inner"> <h1 id="special-input-logo" class="search_logo"></h1> <form id="sform" name="search" role="search" action="https://search.naver.com/search.naver" method="get"> <fieldset> <legend class="blind">검색</legend> <input type="hidden" name="where" value="nexearch"/> <input type="hidden" id="sm" name="sm" value="top_hty"/> <input type="hidden" id="fbm" name="fbm" value="0"/> <input type="hidden" id="acr" name="acr" value="" disabled="disabled"/> <input type="hidden" id="acq" name="acq" value="" disabled="disabled"/> <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled"/> <input type="hidden" id="ie" name="ie" value="utf8"/> <input type="hidden" id="acir" name="acir" value="" disabled="disabled"/> <input type="hidden" id="os" name="os" value="" disabled="disabled"/> <input type="hidden" id="bid" name="bid" value="" disabled="disabled"/> <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled"/> <input type="hidden" id="eid" name="eid" value="" disabled="disabled"/> <input type="hidden" id="mra" name="mra" value="" disabled="disabled"/> <div class="search_input_box"> <input id="query" type="search" name="query" class="search_input" maxlength="255" autocomplete="off" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." role="combobox" aria-expanded="false" aria-haspopup="listbox" aria-owns="autoFrame" aria-controls="" aria-autocomplete="list" aria-activedescendant="" data-atcmp-element=""> </div> <button type="submit" class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})'> <span class="ico_btn_search_svg"> <svg id="search-btn" viewBox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"/> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button id="ke_kbd_btn" type="button" class="btn_keyboard" aria-pressed="false"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button id="nautocomplete" type="button" class="btn_arrow" data-atcmp-element> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right"></div> <div id="shortcutArea" class="shortcut_area" role="navigation" aria-label="주요 서비스"></div> <div id="topAsideArea" class="menu_area"></div> <div id="topPayArea" class="pay_area"></div> <div id="topTalkArea" class="talk_area"></div> <div id="topNotiArea" class="notify_area"></div> <div id="topShoppingArea" class="shopping_area"></div> </div> </div> <div id="container" role="main"> <div id="ad_premium_area" class="ad_premium_area" style="min-width:1920px"> </div> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div>      <script> window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20260426233349',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),i=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(i&&i.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),i&&i.setAttribute("class","ico_btn_search type_color"),i&&i.setAttribute("style","fill: "+t)}var e=function(){if(!window["EAGER-DATA"].GV.isBirthday)return null;const t=window["EAGER-DATA"].GV.svt;return/^[0-9]{4}(06|07|08)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20250825_0/upload_1756126598310vru58.png",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20250825_0/upload_175612662068439LsF.png",textColor:"#0E9FF2"},input:{showSearchLogo:!0,color:"#0E9FF2",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.summer.n.png"}}:/^[0-9]{4}(09|10|11)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20250828_0/pc_birth_9_10_11.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20250918_0/pc_birth_9_10_11_dark.gif",textColor:"#FF6700"},input:{showSearchLogo:!0,color:"#FF6700",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.fall.n.png"}}:/^[0-9]{4}(12|01|02)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20251209_0/pc_birth_12_1_2.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20251209_0/pc_birth_12_1_2_dark.gif",textColor:"#895bd2"},input:{showSearchLogo:!0,color:"#895bd2",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.winter.n.png"}}:/^[0-9]{4}(03|04|05)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/spring.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/spring.dark.gif",textColor:"#f86391"},input:{showSearchLogo:!0,color:"#f86391",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.spring.n.png"}}:null}(),i=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!(e||i&&i.items&&i.items.length>0!=!1))return void t();const o=!e&&i.items[0]?.content?.logo?.isWedding?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.wedding.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.wedding.dark.gif",textColor:"#0091F3",textColorDark:"#3AAFFE",isWedding:!0},input:{color:"#3AAFFE"}}:null;var s=function(){if(e){const t=e;return Object.assign(t.logo,{alt:"생일 축하 합니다.",top:0,left:0,clickAreaList:[{left:0,top:0,height:240,width:639,url:"https://mkt.naver.com/p1/atrb?channel_id=naver_pcspeciallogo&campaign_id=2311-logo-001&target=https%3A%2F%2Fnaver.me%2FxguXFZwP%3Fdtm_source%3Dnaver_pcspeciallogo%26dtm_medium%3Dmktatrb_mn%26dtm_campaign%3D2311-logo-001",alt:"생일 축하 합니다.",clickCode:"top.hbdlogo"}],isBirthday:!0}),{content:t}}if(o)return{content:o};var t=Math.floor(Math.random()*i.items.length);return i.items[t]}();i.items=[s];const a=s&&s.content?s.content.input:null;t(a&&a.color);const n=document.getElementById("search"),c=n&&(!a||!a.showSearchLogo);c&&n.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?c&&n.classList.remove("type_special_logo_full"):c&&n.classList.add("type_special_logo_full")});var l=a&&a.placeholder;if(l){var r=document.getElementById("query");r&&l&&r.setAttribute("title",l),r&&l&&r.setAttribute("placeholder",l)}}()</script> </body> </html>
# <a class="brand-name" href="https://www.youtube.com/channel/UCHwhZ7HPBhUh2IscPSL0pHA" target="_blank"><i class="fa fa-youtube"></i>스타트코딩</a>

# %%
soup.select_one('.brand-name').text
# Out:
# '스타트코딩'

# %%
soup.select_one('.brand-name').attrs
# Out:
# {'class': ['brand-name'],
#  'href': 'https://www.youtube.com/channel/UCHwhZ7HPBhUh2IscPSL0pHA',
#  'target': '_blank'}

# %%
soup.select_one('.brand-name').attrs['href']
# Out:
# 'https://www.youtube.com/channel/UCHwhZ7HPBhUh2IscPSL0pHA'

# %%
soup.select_one('.brand-name').attrs['target']
# Out:
# '_blank'
